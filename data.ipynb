# %%
import os, pandas as pd
import numpy as np

# %%
for dirpath, dirnames, filenames in os.walk("test"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 101 directories and 1 images in 'test'.
# There are 0 directories and 250 images in 'test/foie_gras'.
# There are 0 directories and 250 images in 'test/club_sandwich'.
# There are 0 directories and 250 images in 'test/cheese_plate'.
# There are 0 directories and 250 images in 'test/cup_cakes'.
# There are 0 directories and 250 images in 'test/garlic_bread'.
# There are 0 directories and 250 images in 'test/gnocchi'.
# There are 0 directories and 250 images in 'test/ice_cream'.
# There are 0 directories and 250 images in 'test/samosa'.
# There are 0 directories and 250 images in 'test/donuts'.
# There are 0 directories and 250 images in 'test/tuna_tartare'.
# There are 0 directories and 250 images in 'test/filet_mignon'.
# There are 0 directories and 250 images in 'test/seaweed_salad'.
# There are 0 directories and 250 images in 'test/french_toast'.
# There are 0 directories and 250 images in 'test/chicken_curry'.
# There are 0 directories and 250 images in 'test/shrimp_and_grits'.
# There are 0 directories and 250 images in 'test/steak'.
# There are 0 directories and 250 images in 'test/cheesecake'.
# There are 0 directories and 250 images in 'test/red_velvet_cake'.
# There are 0 directories and 250 images in 'test/waffles'.
# There are 0 directories and 250 images in 'test/churros'.
# There are 0 directories and 250 images in 'test/gyoza'.
# There are 0 directories and 250 images in 'test/lobster_roll_sandwich'.
# There are 0 directories and 250 images in 'test/huevos_rancheros'.
# There are 0 directories and 250 images in 'test/breakfast_burrito'.
# There are 0 directories and 250 images in 'test/grilled_cheese_sandwich'.
# There are 0 directories and 250 images in 'test/spaghetti_bolognese'.
# There are 0 directories and 250 images in 'test/falafel'.
# There are 0 directories and 250 images in 'test/poutine'.
# There are 0 directories and 250 images in 'test/greek_salad'.
# There are 0 directories and 250 images in 'test/beef_tartare'.
# There are 0 directories and 250 images in 'test/fried_calamari'.
# There are 0 directories and 250 images in 'test/guacamole'.
# There are 0 directories and 250 images in 'test/ravioli'.
# There are 0 directories and 250 images in 'test/lobster_bisque'.
# There are 0 directories and 250 images in 'test/beet_salad'.
# There are 0 directories and 250 images in 'test/risotto'.
# There are 0 directories and 250 images in 'test/crab_cakes'.
# There are 0 directories and 250 images in 'test/strawberry_shortcake'.
# There are 0 directories and 250 images in 'test/edamame'.
# There are 0 directories and 250 images in 'test/ceviche'.
# There are 0 directories and 250 images in 'test/hot_and_sour_soup'.
# There are 0 directories and 250 images in 'test/spring_rolls'.
# There are 0 directories and 250 images in 'test/sashimi'.
# There are 0 directories and 250 images in 'test/paella'.
# There are 0 directories and 250 images in 'test/clam_chowder'.
# There are 0 directories and 250 images in 'test/miso_soup'.
# There are 0 directories and 250 images in 'test/escargots'.
# There are 0 directories and 250 images in 'test/hot_dog'.
# There are 0 directories and 250 images in 'test/pulled_pork_sandwich'.
# There are 0 directories and 250 images in 'test/bruschetta'.
# There are 0 directories and 250 images in 'test/panna_cotta'.
# There are 0 directories and 250 images in 'test/fish_and_chips'.
# There are 0 directories and 250 images in 'test/pad_thai'.
# There are 0 directories and 250 images in 'test/tiramisu'.
# There are 0 directories and 250 images in 'test/takoyaki'.
# There are 0 directories and 250 images in 'test/macarons'.
# There are 0 directories and 250 images in 'test/apple_pie'.
# There are 0 directories and 250 images in 'test/cannoli'.
# There are 0 directories and 250 images in 'test/scallops'.
# There are 0 directories and 250 images in 'test/frozen_yogurt'.
# There are 0 directories and 250 images in 'test/chicken_quesadilla'.
# There are 0 directories and 250 images in 'test/mussels'.
# There are 0 directories and 250 images in 'test/beef_carpaccio'.
# There are 0 directories and 250 images in 'test/eggs_benedict'.
# There are 0 directories and 250 images in 'test/spaghetti_carbonara'.
# There are 0 directories and 250 images in 'test/omelette'.
# There are 0 directories and 250 images in 'test/sushi'.
# There are 0 directories and 250 images in 'test/chocolate_mousse'.
# There are 0 directories and 250 images in 'test/beignets'.
# There are 0 directories and 250 images in 'test/bibimbap'.
# There are 0 directories and 250 images in 'test/hummus'.
# There are 0 directories and 250 images in 'test/pork_chop'.
# There are 0 directories and 250 images in 'test/chicken_wings'.
# There are 0 directories and 250 images in 'test/grilled_salmon'.
# There are 0 directories and 250 images in 'test/chocolate_cake'.
# There are 0 directories and 250 images in 'test/tacos'.
# There are 0 directories and 250 images in 'test/hamburger'.
# There are 0 directories and 250 images in 'test/baby_back_ribs'.
# There are 0 directories and 250 images in 'test/pancakes'.
# There are 0 directories and 250 images in 'test/prime_rib'.
# There are 0 directories and 250 images in 'test/pizza'.
# There are 0 directories and 250 images in 'test/nachos'.
# There are 0 directories and 250 images in 'test/macaroni_and_cheese'.
# There are 0 directories and 250 images in 'test/bread_pudding'.
# There are 0 directories and 250 images in 'test/ramen'.
# There are 0 directories and 250 images in 'test/croque_madame'.
# There are 0 directories and 250 images in 'test/lasagna'.
# There are 0 directories and 250 images in 'test/peking_duck'.
# There are 0 directories and 250 images in 'test/deviled_eggs'.
# There are 0 directories and 250 images in 'test/french_fries'.
# There are 0 directories and 250 images in 'test/dumplings'.
# There are 0 directories and 250 images in 'test/fried_rice'.
# There are 0 directories and 250 images in 'test/french_onion_soup'.
# There are 0 directories and 250 images in 'test/pho'.
# There are 0 directories and 250 images in 'test/caprese_salad'.
# There are 0 directories and 250 images in 'test/oysters'.
# There are 0 directories and 250 images in 'test/baklava'.
# There are 0 directories and 250 images in 'test/creme_brulee'.
# There are 0 directories and 250 images in 'test/carrot_cake'.
# There are 0 directories and 250 images in 'test/onion_rings'.
# There are 0 directories and 250 images in 'test/caesar_salad'.

# %%
def add_text_and_func(text: str = None, class_name: str = None, dataframe: pd.DataFrame = None) -> pd.DataFrame:
    if text is None or class_name is None:
        print("AttributeError: Some input(s) are missing.")
        return None
    
    text = text.replace('\n', '')
    query_list = text.split('.')
    query_list = query_list[:len(query_list)-1]
    
    new_rows = pd.DataFrame({'String': query_list, 'Class': [class_name] * len(query_list)})
    
    if dataframe is None or dataframe.empty:
        dataframe = new_rows
    else:
        dataframe = pd.concat([dataframe, new_rows], ignore_index=True)
    return dataframe

# %%
class_list = os.listdir("test")
class_list.remove('.DS_Store')
len(class_list)
# Out:
# 101

# %%
# df.to_csv("queries.csv",index=False)

# %%
df = pd.read_csv("queries.csv")
df
# Out:
#                                                 String      Class
# 0                    Rich and buttery delicacy recipes  foie_gras
# 1                  Luxurious appetizer with duck liver  foie_gras
# 2                   Indulgent gourmet dish preparation  foie_gras
# 3                        Recipes for savory liver pâté  foie_gras
# 4           Delicate and decadent French cuisine ideas  foie_gras
# ..                                                 ...        ...
# 141  Tips for achieving the perfect texture in pota...    gnocchi
# 142  Italian appetizers featuring savory potato dum...    gnocchi
# 143            Creative ways to serve leftover gnocchi    gnocchi
# 144  Seasoning blends for enhancing the flavor of p...    gnocchi
# 145    Serving suggestions for meals featuring gnocchi    gnocchi
#
# [146 rows x 2 columns]

# %%
class_list
# Out:
# ['foie_gras',
#  'club_sandwich',
#  'cheese_plate',
#  'cup_cakes',
#  'garlic_bread',
#  'gnocchi',
#  'ice_cream',
#  'samosa',
#  'donuts',
#  'tuna_tartare',
#  'filet_mignon',
#  'seaweed_salad',
#  'french_toast',
#  'chicken_curry',
#  'shrimp_and_grits',
#  'steak',
#  'cheesecake',
#  'red_velvet_cake',
#  'waffles',
#  'churros',
#  'gyoza',
#  'lobster_roll_sandwich',
#  'huevos_rancheros',
#  'breakfast_burrito',
#  'grilled_cheese_sandwich',
#  'spaghetti_bolognese',
#  'falafel',
#  'poutine',
#  'greek_salad',
#  'beef_tartare',
#  'fried_calamari',
#  'guacamole',
#  'ravioli',
#  'lobster_bisque',
#  'beet_salad',
#  'risotto',
#  'crab_cakes',
#  'strawberry_shortcake',
#  'edamame',
#  'ceviche',
#  'hot_and_sour_soup',
#  'spring_rolls',
#  'sashimi',
#  'paella',
#  'clam_chowder',
#  'miso_soup',
#  'escargots',
#  'hot_dog',
#  'pulled_pork_sandwich',
#  'bruschetta',
#  'panna_cotta',
#  'fish_and_chips',
#  'pad_thai',
#  'tiramisu',
#  'takoyaki',
#  'macarons',
#  'apple_pie',
#  'cannoli',
#  'scallops',
#  'frozen_yogurt',
#  'chicken_quesadilla',
#  'mussels',
#  'beef_carpaccio',
#  'eggs_benedict',
#  'spaghetti_carbonara',
#  'omelette',
#  'sushi',
#  'chocolate_mousse',
#  'beignets',
#  'bibimbap',
#  'hummus',
#  'pork_chop',
#  'chicken_wings',
#  'grilled_salmon',
#  'chocolate_cake',
#  'tacos',
#  'hamburger',
#  'baby_back_ribs',
#  'pancakes',
#  'prime_rib',
#  'pizza',
#  'nachos',
#  'macaroni_and_cheese',
#  'bread_pudding',
#  'ramen',
#  'croque_madame',
#  'lasagna',
#  'peking_duck',
#  'deviled_eggs',
#  'french_fries',
#  'dumplings',
#  'fried_rice',
#  'french_onion_soup',
#  'pho',
#  'caprese_salad',
#  'oysters',
#  'baklava',
#  'creme_brulee',
#  'carrot_cake',
#  'onion_rings',
#  'caesar_salad']

# %%
class_list[100]
# Out:
# 'caesar_salad'

# %%
text = """Fresh salad with crisp romaine lettuce and tangy dressing.
Homemade salad perfect for light lunches or starters.
Recipes for classic Caesar salad with crunchy croutons and Parmesan cheese.
Refreshing and satisfying option ideal for summer meals.
Easy-to-make salad with simple ingredients like anchovies and garlic.
Creative variations of Caesar salad with additions like grilled chicken or shrimp.
Exquisite salad showcasing the balance of flavors and textures.
Homemade Caesar salad with a creamy dressing and savory toppings.
Preparation tips for tossing salad ingredients together and dressing evenly.
Recipes for Caesar salad with a sprinkle of black pepper or lemon juice.
Topping ideas for garnishing Caesar salad, such as bacon bits or avocado slices.
Simple recipes for salads featuring homemade Caesar dressing.
Assembly tutorials for arranging Caesar salad on a plate or in a bowl.
Ideas for serving with a side of crusty bread or grilled vegetables.
Quick and easy Caesar salad recipes for satisfying hunger.
Homemade salad with a crisp and refreshing taste.
Flavorful Caesar salad with a hint of Worcestershire sauce or Dijon mustard.
Twists of Caesar salad with added ingredients like sun-dried tomatoes or olives.
Recipe adaptations for dietary preferences featuring Caesar salad.
Tips for selecting the best quality romaine lettuce and Parmesan cheese for Caesar salad.
Salads featuring homemade classic Caesar dressing.
Creative ways to serve Caesar salad for picnics or outdoor gatherings.
Dressing blends for enhancing the flavor of Caesar salad.
Serving suggestions for dishes featuring Caesar salad."""
df = add_text_and_func(text,class_list[100],df)
df.to_csv("queries.csv",index=False)
df
# Out:
#                                                  String         Class
# 0                     Rich and buttery delicacy recipes     foie_gras
# 1                   Luxurious appetizer with duck liver     foie_gras
# 2                    Indulgent gourmet dish preparation     foie_gras
# 3                         Recipes for savory liver pâté     foie_gras
# 4            Delicate and decadent French cuisine ideas     foie_gras
# ...                                                 ...           ...
# 2475  Tips for selecting the best quality romaine le...  caesar_salad
# 2476  Salads featuring homemade classic Caesar dressing  caesar_salad
# 2477  Creative ways to serve Caesar salad for picnic...  caesar_salad
# 2478  Dressing blends for enhancing the flavor of Ca...  caesar_salad
# 2479  Serving suggestions for dishes featuring Caesa...  caesar_salad
#
# [2480 rows x 2 columns]
